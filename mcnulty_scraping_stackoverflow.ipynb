# %% [markdown]
# # Project McNulty - Scraping the Links for All Python-Related Questions
#
# Paul Lim, Katharina Huang, Thaddeus Norman
#
# 05/17/2017

# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests
from bs4 import BeautifulSoup
import time

from fake_useragent import UserAgent

# %% [markdown]
# ## Getting Question Links

# %% [markdown]
# ### Start with an example url

# %%
url_ex = 'http://stackoverflow.com/questions/tagged/python?page=14865&sort=newest&pagesize=50'
link_ex = requests.get(url_ex)
page_ex = link_ex.text
soup_ex = BeautifulSoup(page_ex, 'lxml')

# %% [markdown]
# ### Get a sample link and the question text

# %%
questions_class_ex = soup_ex.find('div', {'class': 'question-summary'})
questions_div_ex = questions_class_ex.find('div', {'class': 'summary'})
questions_link_ex = questions_div_ex.find('a', href=True).get('href')
questions_text_ex = questions_div_ex.find('a').getText()
questions_text_ex
# Out:
# 'Python - How to use Conch to create a Virtual SSH server'

# %% [markdown]
# ### Try looping through the entire page and get all links and questions

# %%
all_question_summaries_ex = soup_ex.find_all('div', {'class': 'question-summary'})
link_list_ex = []
question_list_ex = []
view_count_list_ex = []

for question in all_question_summaries_ex:
    div_ex = question.find('div', {'class': 'summary'})
    link_ex = div_ex.find('a', href=True).get('href')
    text_ex = div_ex.find('a').getText()
    
    stats_ex = question.find('div', {'class': 'statscontainer'})
    view_ex = stats_ex.find_all('div')[-1].getText().strip('\r\n ').strip(' views')
    
    link_list_ex.append(link_ex)
    question_list_ex.append(text_ex)
    view_count_list_ex.append(view_ex)

# print(link_list_ex)
# print(question_list_ex)
print(view_count_list_ex)
# Out:
# ['2k', '27k', '377', '191k', '3k', '44k', '43k', '12k', '901', '192k', '7k', '15k', '2k', '1k', '146k', '2k', '1k', '700', '980', '2k', '3k', '5k', '15k', '447k', '139k', '8k', '68k', '57k', '2k', '146k', '4k', '210k', '6k', '12k', '3k', '288', '30k', '645', '829', '3k', '64k', '32k', '3k', '2k', '1.6m', '3k', '5k', '2k', '188k', '591']

# %% [markdown]
# ### Create a function that will loop through multiple pages

# %%
def scrape_links(url_template, start_page, end_page, delay=5):
    '''
    url_template should look like this: 
        http://stackoverflow.com/questions/tagged/python?page={page}&sort=newest&pagesize=50
    start_page should be LESS THAN end_page
    '''
    df = pd.DataFrame(columns = ['links','questions','views'])

    link_list = []
    question_list = []
    view_list = []
    ua = UserAgent()

        
    for i in range(start_page, end_page):
        url = url_template.format(page=start_page)
        user_agent = {'User-agent': ua.random}
        print(user_agent)
        
        try:
            link = requests.get(url, headers = user_agent)
            start_page += 1
        except:
            print(url)
            print('Check to make sure the URL is correct!')
            
        page = link.text
        soup = BeautifulSoup(page, 'lxml')
        
        all_question_summaries = soup.find_all('div', {'class': 'question-summary'})
        
        if all_question_summaries:
            for question in all_question_summaries:
                div = question.find('div', {'class': 'summary'})
                link_str = div.find('a', href=True).get('href')
                
                text = div.find('a').getText()

                stats = question.find('div', {'class': 'statscontainer'})
                view = stats.find_all('div')[-1].getText().strip('\r\n ').strip(' views')
                view = view.replace('k','E+03').replace('m','E+06')

                link_list.append('http://stackoverflow.com' + link_str)
                question_list.append(text)
                view_list.append(view)
        else:
            print(url)
            print('No question-summary class found!')
            
        df = pd.DataFrame({'links': link_list, 'questions': question_list, 'views': view_list})
#         df['links'] = link_list
#         df['questions'] = question_list
#         df['views'] = view_list
        df = df.drop_duplicates()
        
        df.to_csv('links.csv')
            
#         with open('links.csv', 'a') as f:
#             df.to_csv(f, header=False)
            
        time.sleep(delay + 2*np.random.rand())
        
    return df

# %% [markdown]
# ## Getting Data From Each Individual Question Page

# %% [markdown]
# ### Start with an example url

# %%
url_ex2 = 'http://stackoverflow.com/questions/469/how-can-i-find-the-full-path-to-a-font-from-its-display-name-on-a-mac'
link_ex2 = requests.get(url_ex2)
page_ex2 = link_ex2.text
soup_ex2 = BeautifulSoup(page_ex2, 'lxml')

# %% [markdown]
# ### Get the user information

# %%
users_ex = soup_ex2.find('div', {'class': 'user-details'})

badges_ex = users_ex.find_all('span', {'class': 'badgecount'})
for badge in badges_ex:
    print(badge.getText())
    
id_ex = users_ex.find('a', href=True)
# Out:
# 9
# 27
# 60
# <a href="/users/1997093/task">TAsk</a>

# %% [markdown]
# ### Try looping through one page

# %%
all_users_ex = soup_ex2.find_all('div', {'class': 'user-details'})
badge_list_ex = []
id_list_ex = []

for user in all_users_ex:
    badges_ex2 = user.find_all('span', {'class': 'badgecount'})
    temp_badge_list_ex = []
    
    for badge in badges_ex2:
        temp_badge_list_ex.append(int(badge.getText()))
    badge_list_ex.append(temp_badge_list_ex)
    
    id_list_ex.append(users_ex.find('a', href=True))

# print(badge_list_ex)
# print(id_list_ex)

df_ex = pd.DataFrame(badge_list_ex, columns=['gold','silver','bronze'])
df_ex['id'] = id_list_ex

df_ex.head()
# Out:
#    gold  silver  bronze                                      id
# 0     9      27    60.0  <a href="/users/1997093/task">TAsk</a>
# 1    10      36    46.0  <a href="/users/1997093/task">TAsk</a>
# 2     1      27    43.0  <a href="/users/1997093/task">TAsk</a>
# 3     4      34    57.0  <a href="/users/1997093/task">TAsk</a>
# 4     9      44    88.0  <a href="/users/1997093/task">TAsk</a>

# %% [markdown]
# ### Create a function that will loop through multiple pages

# %%
def scrape_users(link_list, delay=5):
    badge_list = []
    id_list = []
    ua = UserAgent()
        
    for link in link_list:
        url = link
        user_agent = {'User-agent': ua.random}
        print(user_agent)
        
        try:
            link = requests.get(url, headers = user_agent)

        except:
            print(url)
            print('Check to make sure the URL is correct!')
            
        page = link.text
        soup = BeautifulSoup(page, 'lxml')
        
        all_users = soup.find_all('div', {'class': 'user-details'})
        
        if all_users:
            for user in all_users:
                badges = user.find_all('span', {'class': 'badgecount'})
                temp_badge_list = []

                for badge in badges:
                    temp_badge_list.append(int(badge.getText()))
                badge_list.append(temp_badge_list)

                id_list.append(user.find('a', href=True))
            
            time.sleep(delay + 2*np.random.rand())
        else:
            print(url)
            print('No users found!')

            
    df = pd.DataFrame(badge_list, columns=['gold','silver','bronze'])
    df['id'] = id_list
    df = df.drop_duplicates(keep='last')
    df = df.dropna(how='all')
    
    df.to_csv('users.csv')

    return df

# %% [markdown]
# ## Test Cells

# %% [markdown]
# ### Testing the individual page scraping

# %%
url_t = ['http://stackoverflow.com/questions/8724352/getting-the-nth-element-using-beautifulsoup']

df_t = scrape_users(url_t)
df_t
# Out:
# {'User-agent': 'Mozilla/5.0 (Windows NT 6.2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1464.0 Safari/537.36'}
#    gold  silver  bronze                                                 id
# 0   1.0     3.0    11.0        <a href="/users/2584/aadvaark">aadvaark</a>
# 1   4.0    56.0    91.0      <a href="/users/183066/jcollado">jcollado</a>
# 5   9.0    96.0   132.0  <a href="/users/667301/mike-pennington">Mike P...

# %% [markdown]
# ### Testing the link scraping

# %%
ex2 = 'http://stackoverflow.com/questions/tagged/python?page={page}&sort=newest&pagesize=50'

df_ex2 = scrape_links(ex2, 14868, 14869)
df_ex2
# Out:
# {'User-agent': 'Mozilla/5.0 (Windows NT 5.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.2117.157 Safari/537.36'}
#                                                 links  \
# 0   http://stackoverflow.com/questions/279782/how-...
# 1   http://stackoverflow.com/questions/279707/maki...
# 2   http://stackoverflow.com/questions/279561/what...
# 3   http://stackoverflow.com/questions/279434/pyth...
# 4   http://stackoverflow.com/questions/279237/impo...
# 5   http://stackoverflow.com/questions/279129/can-...
# 6   http://stackoverflow.com/questions/279119/how-...
# 7   http://stackoverflow.com/questions/279094/how-...
# 8   http://stackoverflow.com/questions/277965/dict...
# 9   http://stackoverflow.com/questions/277922/pyth...
# 10  http://stackoverflow.com/questions/277187/is-t...
# 11  http://stackoverflow.com/questions/277170/is-t...
# 12  http://stackoverflow.com/questions/276769/how-...
# 13  http://stackoverflow.com/questions/276761/expo...
# 14  http://stackoverflow.com/questions/276679/how-...
# 15  http://stackoverflow.com/questions/276656/can-...
# 16  http://stackoverflow.com/questions/276434/conv...
# 17  http://stackoverflow.com/questions/276345/synt...
# 18  http://stackoverflow.com/questions/276286/how-...
# 19  http://stackoverflow.com/questions/276281/cpu-...
# 20  http://stackoverflow.com/questions/276266/what...
# 21  http://stackoverflow.com/questions/276184/wcf-...
# 22  http://stackoverflow.com/questions/276052/how-...
# 23  http://stackoverflow.com/questions/275989/remo...
# 24  http://stackoverflow.com/questions/275980/impo...
# 25  http://stackoverflow.com/questions/275756/what...
# 26  http://stackoverflow.com/questions/275683/how-...
# 27  http://stackoverflow.com/questions/275572/data...
# 28  http://stackoverflow.com/questions/275541/info...
# 29  http://stackoverflow.com/questions/275207/pyth...
# 30  http://stackoverflow.com/questions/275174/how-...
# 31  http://stackoverflow.com/questions/275109/what...
# 32  http://stackoverflow.com/questions/275018/how-...
# 33  http://stackoverflow.com/questions/274638/conf...
# 34  http://stackoverflow.com/questions/274493/how-...
# 35  http://stackoverflow.com/questions/274361/utf-...
# 36  http://stackoverflow.com/questions/273946/how-...
# 37  http://stackoverflow.com/questions/273937/how-...
# 38  http://stackoverflow.com/questions/273698/is-t...
# 39  http://stackoverflow.com/questions/273612/pyth...
# 40  http://stackoverflow.com/questions/273524/pyth...
# 41  http://stackoverflow.com/questions/273203/acce...
# 42  http://stackoverflow.com/questions/273192/how-...
# 43  http://stackoverflow.com/questions/273060/test...
# 44  http://stackoverflow.com/questions/273043/pyth...
# 45  http://stackoverflow.com/questions/273002/gene...
# 46  http://stackoverflow.com/questions/272826/pyth...
# 47  http://stackoverflow.com/questions/272233/file...
# 48  http://stackoverflow.com/questions/272188/code...
# 49  http://stackoverflow.com/questions/272042/user...
#
#                                             questions    views
# 0   How can one get the set of all classes with re...    2E+03
# 1                     making a python GUI [duplicate]    3E+03
# 2   What is the Python equivalent of static variab...  182E+03
# 3               Python: How do I generate a keypress?    3E+03
# 4                Import a module from a relative path  664E+03
# 5   Can anyone recommend a decent FOSS PDF generat...    2E+03
# 6   How do I search for unpublished Plone content ...      963
# 7      How do I script an OLE component using Python?    9E+03
# 8                 Dictionary or If statements, Jython    3E+03
# 9                             Python Argument Binders   13E+03
# 10  Is there a more Pythonic way to merge two HTML...      626
# 11                  Is there a good Python GUI shell?   11E+03
# 12  How to expose std::vector<int> as a Python lis...   12E+03
# 13                       Exposing a C++ API to Python   11E+03
# 14  How to import a python file in python script m...    7E+03
# 15  Can you achieve a case insensitive 'unique' co...    3E+03
# 16     Converting PDF to HTML with Python [duplicate]   24E+03
# 17  Syntax error whenever I put Python code inside...    4E+03
# 18  How to show the visitor a moved web page AND r...      527
# 19                    CPU Usage Per Process in Python   23E+03
# 20  What's a cross platform way to play a sound fi...    7E+03
# 21                                     WCF and Python   17E+03
# 22    How to get current CPU and RAM usage in Python?  144E+03
# 23  Remote debugging of multi threaded Python Appl...    1E+03
# 24           import mechanize module to python script    2E+03
# 25  What's the difference between all of the os.po...    3E+03
# 26  How do you get a thumbnail of a movie using IM...    6E+03
# 27               Database change underneath SQLObject      755
# 28  information seemingly coming out of mysqldb in...      272
# 29                   Python ctypes and function calls    3E+03
# 30  How do I perform HTML decoding/encoding using ...  129E+03
# 31  What is the regular expression for /urlchecker...      202
# 32      How can I remove (chomp) a newline in Python?  955E+03
# 33  config_vars.mk missing in default xampp-linux ...    2E+03
# 34  How to copy a file in Python with a progress bar?   13E+03
# 35     UTF-8 latin-1 conversion issues, python django   10E+03
# 36  How do I resize an image using PIL and maintai...  230E+03
# 37  How do I Create an instance of a class in anot...    1E+03
# 38  Is there a cross-platform way of getting infor...    9E+03
# 39  python - check at the end of the loop if need ...    3E+03
# 40                  Python 3.0 and language evolution    1E+03
# 41  Access second result set of stored procedure w...    2E+03
# 42  How to check if a directory exists and create ...  1.2E+06
# 43                      Testing Web Services Consumer    1E+03
# 44                   Python memory debugging with GDB    3E+03
# 45          Generating a WSDL using Python and SOAPpy   21E+03
# 46              Python's os.execvp equivalent for PHP      486
# 47  “File -X: does not exist” message from ipy.exe...      357
# 48      Code Coverage and Unit Testing of Python Code   10E+03
# 49                      User Authentication in Django    1E+03
